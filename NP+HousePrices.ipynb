# %% [markdown]
#   ## Comparing house prices of those in and outside of England's and Wales National Park's
#   ## Part 1, extracting Population data and creating a new df

# %%
import pandas as pd

# %% [markdown]
#  ## Exploring the population data

# %%
df = pd.read_csv("datadownload.csv")

# %%
df
# Out:
#    Figure 1: The population declined in several national parks between 2011 and 2021  \
# 0   Usual resident population, national parks in E...
# 1                                                 NaN
# 2                                             Notes:
# 3                                                 NaN
# 4                                       National park
# 5                                  Bannau Brycheiniog
# 6                                            Dartmoor
# 7                                               Eryri
# 8                                              Exmoor
# 9                                       Lake District
# 10                                         New Forest
# 11                                   North York Moors
# 12                                     Northumberland
# 13                                      Peak District
# 14                                Pembrokeshire Coast
# 15                                        South Downs
# ...

# %%
df = df.iloc[5:]

# %%
df
# Out:
#    Figure 1: The population declined in several national parks between 2011 and 2021  \
# 5                                  Bannau Brycheiniog
# 6                                            Dartmoor
# 7                                               Eryri
# 8                                              Exmoor
# 9                                       Lake District
# 10                                         New Forest
# 11                                   North York Moors
# 12                                     Northumberland
# 13                                      Peak District
# 14                                Pembrokeshire Coast
# 15                                        South Downs
# 16                                         The Broads
# 17                                    Yorkshire Dales
# 18                                                NaN
# 19  Source: Office for National Statistics - 2011 ...
#
#    Unnamed: 1 Unnamed: 2
# 5      33,344     33,485
# ...

# %%
df = df.reset_index(drop=True)

# %%
df
# Out:
#    Figure 1: The population declined in several national parks between 2011 and 2021  \
# 0                                  Bannau Brycheiniog
# 1                                            Dartmoor
# 2                                               Eryri
# 3                                              Exmoor
# 4                                       Lake District
# 5                                          New Forest
# 6                                    North York Moors
# 7                                      Northumberland
# 8                                       Peak District
# 9                                 Pembrokeshire Coast
# 10                                        South Downs
# 11                                         The Broads
# 12                                    Yorkshire Dales
# 13                                                NaN
# 14  Source: Office for National Statistics - 2011 ...
#
#    Unnamed: 1 Unnamed: 2
# 0      33,344     33,485
# ...

# %%
df.columns = ["National Park", "2011 total", "2021 total"]

# %%
df
# Out:
#                                         National Park 2011 total 2021 total
# 0                                  Bannau Brycheiniog     33,344     33,485
# 1                                            Dartmoor     33,596     34,124
# 2                                               Eryri     25,702     24,416
# 3                                              Exmoor     10,273     10,192
# 4                                       Lake District        NaN     38,993
# 5                                          New Forest     34,922     34,166
# 6                                    North York Moors     23,380     22,935
# 7                                      Northumberland      1,993      1,848
# 8                                       Peak District     37,905     35,901
# 9                                 Pembrokeshire Coast     22,644     20,922
# 10                                        South Downs    112,343    113,339
# ...

# %%
df = df.iloc[:-2]
df
# Out:
#           National Park 2011 total 2021 total
# 0    Bannau Brycheiniog     33,344     33,485
# 1              Dartmoor     33,596     34,124
# 2                 Eryri     25,702     24,416
# 3                Exmoor     10,273     10,192
# 4         Lake District        NaN     38,993
# 5            New Forest     34,922     34,166
# 6      North York Moors     23,380     22,935
# 7        Northumberland      1,993      1,848
# 8         Peak District     37,905     35,901
# 9   Pembrokeshire Coast     22,644     20,922
# 10          South Downs    112,343    113,339
# 11           The Broads      6,271      6,275
# 12      Yorkshire Dales        NaN     22,798

# %%
 # df.to_csv("NationalParkPopulationData.csv", index = False)
 # commented out to prevent duplicate csv files appearing every time the notebook is ran
